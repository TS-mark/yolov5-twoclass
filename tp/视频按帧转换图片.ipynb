# %%
# 导入所需要的库
import cv2
import numpy as np
 
 
# 定义保存图片函数
# image:要保存的图片名字
# addr；图片地址与相片名字的前部分
# num: 相片，名字的后缀。int 类型
def save_image(image, addr, num):
        address = addr + str(num) + '.jpg'
        cv2.imwrite(address, image)
 
 
# 读取视频文件 视频文件路径
videoCapture = cv2.VideoCapture(r"C:\Users\mark\Documents\yolov7-main\inference\images\yanshishipin.mp4")
# 通过摄像头的方式
# videoCapture=cv2.VideoCapture(1)
 
# 读帧
success, frame = videoCapture.read()
i = 0
timeF = 10
j = 0
while success:
    i = i + 1
    if (i % timeF == 0):
        j = j + 1
        save_image(frame, r'./added_data', j) #视频截成图片存放的位置
        print('save image:', i)
    success, frame = videoCapture.read()
# Out:
# save image: 10
# save image: 20
# save image: 30
# save image: 40
# save image: 50
# save image: 60
# save image: 70
# save image: 80
# save image: 90
# save image: 100
# save image: 110
# save image: 120
# save image: 130
# save image: 140
# save image: 150
# save image: 160
# save image: 170
# save image: 180
# save image: 190
# save image: 200
# save image: 210
# save image: 220
# save image: 230
# save image: 240
# save image: 250
# save image: 260
# save image: 270
# save image: 280
# save image: 290
# save image: 300
# save image: 310
# save image: 320
# save image: 330
# save image: 340
# save image: 350
# save image: 360
# save image: 370
# save image: 380
# save image: 390
# save image: 400
# save image: 410
# save image: 420
# save image: 430
# save image: 440
# save image: 450
# save image: 460
# save image: 470
# save image: 480
# save image: 490
# save image: 500
# save image: 510
# save image: 520
# save image: 530
# save image: 540
# save image: 550
# save image: 560
# save image: 570
# save image: 580
# save image: 590
# save image: 600
# save image: 610
# save image: 620
# save image: 630
# save image: 640
# save image: 650
# save image: 660
# save image: 670
# save image: 680
# save image: 690
# save image: 700
# save image: 710
# save image: 720
# save image: 730
# save image: 740
# save image: 750
# save image: 760
# save image: 770
# save image: 780
# save image: 790
# save image: 800
# save image: 810
# save image: 820
# save image: 830
# save image: 840
# save image: 850
# save image: 860
# save image: 870
# save image: 880
# save image: 890
# save image: 900
# save image: 910
# save image: 920
# save image: 930
# save image: 940
# save image: 950
# save image: 960
# save image: 970
# save image: 980
# save image: 990
# save image: 1000
# save image: 1010
# save image: 1020
# save image: 1030
# save image: 1040
# save image: 1050
# save image: 1060
# save image: 1070
# save image: 1080
# save image: 1090
# save image: 1100
# save image: 1110
# save image: 1120
# save image: 1130
# save image: 1140
# save image: 1150
# save image: 1160
# save image: 1170
# save image: 1180
# save image: 1190
# save image: 1200
# save image: 1210
# save image: 1220
# save image: 1230
# save image: 1240
# save image: 1250
# save image: 1260
# save image: 1270
# save image: 1280
# save image: 1290
# save image: 1300
# save image: 1310
# save image: 1320
# save image: 1330
# save image: 1340
# save image: 1350
# save image: 1360
# save image: 1370
# save image: 1380
# save image: 1390
# save image: 1400
# save image: 1410
# save image: 1420
# save image: 1430
# save image: 1440
# save image: 1450
# save image: 1460
# save image: 1470
# save image: 1480
# save image: 1490
# save image: 1500
# save image: 1510
# save image: 1520
# save image: 1530
# save image: 1540
# save image: 1550
# save image: 1560
# save image: 1570
# save image: 1580
# save image: 1590
# save image: 1600
# save image: 1610
# save image: 1620
# save image: 1630
# save image: 1640
# save image: 1650
# save image: 1660
# save image: 1670
# save image: 1680
# save image: 1690
# save image: 1700
# save image: 1710
# save image: 1720
# save image: 1730
# save image: 1740
# save image: 1750
# save image: 1760
# save image: 1770
# save image: 1780
# save image: 1790
# save image: 1800
